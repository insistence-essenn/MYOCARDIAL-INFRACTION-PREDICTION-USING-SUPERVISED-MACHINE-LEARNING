# %% [markdown]
# # Data Preprocessing:

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
import pandas as pd

# %%
data = pd.read_csv('heart.csv')

# %%
data
# Out:
#      Age Age.Group  Gender Locality Marital_status Sleep Depression Smoking  \
# 0     45     41-50  Female    RURAL        MARRIED    NO        YES      NO
# 1     51     51-60  Female    URBAN        MARRIED    NO        YES      NO
# 2     55     51-60  Female    RURAL        MARRIED   YES        YES      NO
# 3     55     51-60  Female    RURAL        MARRIED   YES        YES      NO
# 4     56     51-60  Female    RURAL        MARRIED    NO        YES      NO
# ..   ...       ...     ...      ...            ...   ...        ...     ...
# 363   55     51-60    Male    URBAN        MARRIED    NO        YES      NO
# 364   55     51-60    Male    RURAL        MARRIED    NO        YES     YES
# 365   58     51-60    Male    URBAN        MARRIED    NO        YES      NO
# 366   58     51-60    Male    URBAN        MARRIED    NO        YES     YES
# 367   50     41-50    Male    RURAL        MARRIED    NO        YES     YES
#
#      Diabetes     BP  ... chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0           1  100.6  ...  341    1        2      136      1      3.0      2
# 1           0   90.6  ...  305    0        0      142      1      1.2      2
# 2           1  100.7  ...  327    0        1      117      1      3.4      2
# 3           1  160.1  ...  205    0        1      130      1      2.0      2
# 4           1   90.6  ...  288    1        2      133      1      4.0      3
# ..        ...    ...  ...  ...  ...      ...      ...    ...      ...    ...
# 363         0  120.8  ...  274    0        2      166      0      0.5      2
# 364         0  110.7  ...  188    0        0      139      0      2.0      2
# 365         1  130.9  ...  149    0        2      126      0      0.8      1
# 366         0  120.7  ...  243    0        2      128      0      2.6      2
# 367         0  100.6  ...  233    0        0      163      0      0.6      2
#
#      ca  thal  Mortality
# 0     0     7          0
# 1     0     7          0
# 2     0     3          0
# 3     1     7          0
# 4     2     7          0
# ..   ..   ...        ...
# 363   0     7          0
# 364   3     7          0
# 365   3     3          0
# 366   0     7          0
# 367   1     7          0
#
# [368 rows x 23 columns]

# %% [markdown]
# Before removing the null data

# %%
data.shape
# Out:
# (368, 23)

# %% [markdown]
# After removing the null data

# %%
df = data.dropna()

# %%
df.shape
# Out:
# (368, 23)

# %%
df.columns
# Out:
# Index(['Age', 'Age.Group', 'Gender', 'Locality', 'Marital_status', 'Sleep',
#        'Depression', 'Smoking', 'Diabetes', 'BP', 'Hypersensitivity', 'cp',
#        'trestbps', 'chol', 'fbs', 'restecg', 'thalach', 'exang', 'oldpeak',
#        'slope', 'ca', 'thal', 'Mortality'],
#       dtype='object')

# %%
df.isnull().sum()
# Out:
# Age                 0
# Age.Group           0
# Gender              0
# Locality            0
# Marital_status      0
# Sleep               0
# Depression          0
# Smoking             0
# Diabetes            0
# BP                  0
# Hypersensitivity    0
# cp                  0
# trestbps            0
# chol                0
# fbs                 0
# restecg             0
# thalach             0
# exang               0
# oldpeak             0
# slope               0
# ca                  0
# thal                0
# Mortality           0
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 368 entries, 0 to 367
# Data columns (total 23 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Age               368 non-null    int64
#  1   Age.Group         368 non-null    object
#  2   Gender            368 non-null    object
#  3   Locality          368 non-null    object
#  4   Marital_status    368 non-null    object
#  5   Sleep             368 non-null    object
#  6   Depression        368 non-null    object
#  7   Smoking           368 non-null    object
#  8   Diabetes          368 non-null    int64
#  9   BP                368 non-null    float64
#  10  Hypersensitivity  368 non-null    object
#  11  cp                368 non-null    int64
#  12  trestbps          368 non-null    int64
#  13  chol              368 non-null    int64
#  14  fbs               368 non-null    int64
#  15  restecg           368 non-null    int64
#  16  thalach           368 non-null    int64
#  17  exang             368 non-null    int64
#  18  oldpeak           368 non-null    float64
#  19  slope             368 non-null    int64
#  20  ca                368 non-null    int64
#  21  thal              368 non-null    int64
#  22  Mortality         368 non-null    int64
# dtypes: float64(2), int64(13), object(8)
# memory usage: 66.2+ KB

# %%
df.columns
# Out:
# Index(['Age', 'Age.Group', 'Gender', 'Locality', 'Marital_status', 'Sleep',
#        'Depression', 'Smoking', 'Diabetes', 'BP', 'Hypersensitivity', 'cp',
#        'trestbps', 'chol', 'fbs', 'restecg', 'thalach', 'exang', 'oldpeak',
#        'slope', 'ca', 'thal', 'Mortality'],
#       dtype='object')

# %%
df.duplicated()
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 363     True
# 364     True
# 365     True
# 366     True
# 367     True
# Length: 368, dtype: bool

# %%
df.duplicated().sum()
# Out:
# 214

# %%
df.describe()
# Out:
#               Age    Diabetes          BP          cp    trestbps        chol  \
# count  368.000000  368.000000  368.000000  368.000000  368.000000  368.000000
# mean    54.293478    0.461957  121.213315    3.671196  132.741848  248.940217
# std      8.718158    0.499229   24.539205    0.772862   18.194265   50.126453
# min     24.000000    0.000000   80.500000    1.000000  100.000000  131.000000
# 25%     50.750000    0.000000  100.700000    4.000000  120.000000  212.000000
# 50%     55.000000    0.000000  120.800000    4.000000  130.000000  249.000000
# 75%     60.250000    1.000000  140.700000    4.000000  142.000000  283.000000
# max     77.000000    1.000000  190.110000    4.000000  200.000000  409.000000
#
#               fbs     restecg     thalach       exang     oldpeak       slope  \
# count  368.000000  368.000000  368.000000  368.000000  368.000000  368.000000
# mean     0.141304    1.073370  140.923913    0.562500    1.541848    1.842391
# std      0.348809    0.994562   22.994601    0.496754    1.385381    0.564284
# min      0.000000    0.000000   71.000000    0.000000    0.000000    1.000000
# 25%      0.000000    0.000000  125.000000    0.000000    0.275000    1.750000
# 50%      0.000000    2.000000  144.000000    1.000000    1.200000    2.000000
# 75%      0.000000    2.000000  158.000000    1.000000    2.200000    2.000000
# max      1.000000    2.000000  195.000000    1.000000    6.200000    3.000000
#
#                ca        thal   Mortality
# count  368.000000  368.000000  368.000000
# mean     1.002717    5.858696    0.217391
# std      1.037442    1.744319    0.413033
# min      0.000000    3.000000    0.000000
# 25%      0.000000    3.000000    0.000000
# 50%      1.000000    7.000000    0.000000
# 75%      2.000000    7.000000    0.000000
# max      3.000000    7.000000    1.000000

# %%
df.columns
# Out:
# Index(['Age', 'Age.Group', 'Gender', 'Locality', 'Marital_status', 'Sleep',
#        'Depression', 'Smoking', 'Diabetes', 'BP', 'Hypersensitivity', 'cp',
#        'trestbps', 'chol', 'fbs', 'restecg', 'thalach', 'exang', 'oldpeak',
#        'slope', 'ca', 'thal', 'Mortality'],
#       dtype='object')

# %%
df.Gender.unique()
# Out:
# array(['Female', 'Male'], dtype=object)

# %%
df.Locality.unique()
# Out:
# array(['RURAL', 'URBAN'], dtype=object)

# %%
df.BP.unique()
# Out:
# array([100.6 ,  90.6 , 100.7 , 160.1 , 140.7 , 120.8 , 130.8 , 160.9 ,
#        140.9 , 110.7 , 190.11, 160.7 , 150.9 ,  80.5 , 120.9 , 130.9 ,
#        120.7 ])

# %%
df.Age.unique()
# Out:
# array([45, 51, 55, 56, 57, 58, 59, 60, 61, 62, 63, 65, 66, 24, 25, 35, 38,
#        40, 44, 46, 47, 50, 52, 53, 54, 64, 67, 68, 69, 70, 77],
#       dtype=int64)

# %%
df.Smoking.unique()
# Out:
# array(['NO', 'YES'], dtype=object)

# %%
df.Mortality.unique()
# Out:
# array([0, 1], dtype=int64)

# %%
df.Mortality.value_counts()
# Out:
# 0    288
# 1     80
# Name: Mortality, dtype: int64

# %%
pd.crosstab(df.Age,df.Mortality)
# Out:
# Mortality   0   1
# Age
# 24          6   0
# 25          5   0
# 35          5   0
# 38          1   4
# 40          6   4
# 44          0   5
# 45          5   6
# 46          0   5
# 47          4   1
# 50         16  19
# 51         11   0
# 52         23   3
# 53         10   0
# 54         30   0
# 55         35   0
# 56         17   1
# 57          9   1
# 58         18   0
# 59          8   1
# 60         17   0
# 61          5  10
# 62         12  15
# 63         13   5
# 64          4   0
# 65          8   0
# 66          7   0
# 67          6   0
# 68          2   0
# 69          1   0
# 70          3   0
# 77          1   0

# %%
pd.crosstab(df.Gender,df.Mortality)
# Out:
# Mortality    0   1
# Gender
# Female      49  34
# Male       239  46

# %%
df.corr()
# Out:
#                 Age  Diabetes        BP        cp  trestbps      chol  \
# Age        1.000000  0.231081 -0.034220  0.039433  0.300752  0.184823
# Diabetes   0.231081  1.000000  0.013709  0.055767  0.093861  0.087997
# BP        -0.034220  0.013709  1.000000  0.013485 -0.126641 -0.070075
# cp         0.039433  0.055767  0.013485  1.000000  0.010224 -0.009934
# trestbps   0.300752  0.093861 -0.126641  0.010224  1.000000  0.220297
# chol       0.184823  0.087997 -0.070075 -0.009934  0.220297  1.000000
# fbs        0.121626 -0.078578  0.067410  0.051526  0.171493 -0.010892
# restecg    0.128239 -0.090400  0.000630  0.148451  0.154641  0.079503
# thalach   -0.099504 -0.017580  0.026236 -0.195365  0.159584  0.084777
# exang     -0.160281 -0.028842  0.025394  0.305626 -0.028509  0.021161
# oldpeak    0.103862 -0.039453 -0.161551  0.047751  0.132800 -0.048265
# slope      0.147343  0.085054 -0.130320  0.030798  0.095021 -0.117377
# ca         0.438851  0.050180 -0.077802  0.137051  0.158685  0.182081
# thal      -0.261194 -0.090673 -0.082335 -0.004240  0.157167 -0.059587
# Mortality -0.099490  0.317722 -0.041203 -0.040081 -0.098750  0.175142
#
#                 fbs   restecg   thalach     exang   oldpeak     slope  \
# Age        0.121626  0.128239 -0.099504 -0.160281  0.103862  0.147343
# Diabetes  -0.078578 -0.090400 -0.017580 -0.028842 -0.039453  0.085054
# BP         0.067410  0.000630  0.026236  0.025394 -0.161551 -0.130320
# cp         0.051526  0.148451 -0.195365  0.305626  0.047751  0.030798
# trestbps   0.171493  0.154641  0.159584 -0.028509  0.132800  0.095021
# chol      -0.010892  0.079503  0.084777  0.021161 -0.048265 -0.117377
# fbs        1.000000  0.079996  0.039053  0.169049 -0.057943  0.127301
# restecg    0.079996  1.000000  0.028601 -0.045156 -0.060177 -0.052167
# thalach    0.039053  0.028601  1.000000 -0.264365 -0.246837 -0.376399
# exang      0.169049 -0.045156 -0.264365  1.000000  0.129619  0.249092
# oldpeak   -0.057943 -0.060177 -0.246837  0.129619  1.000000  0.637596
# slope      0.127301 -0.052167 -0.376399  0.249092  0.637596  1.000000
# ca         0.081763  0.131847 -0.137970 -0.135155  0.234815  0.056588
# thal       0.014993 -0.100811 -0.055431  0.154872  0.177563  0.157251
# Mortality -0.024669 -0.012401 -0.039567 -0.106243 -0.110228  0.030498
#
#                  ca      thal  Mortality
# Age        0.438851 -0.261194  -0.099490
# Diabetes   0.050180 -0.090673   0.317722
# BP        -0.077802 -0.082335  -0.041203
# cp         0.137051 -0.004240  -0.040081
# trestbps   0.158685  0.157167  -0.098750
# chol       0.182081 -0.059587   0.175142
# fbs        0.081763  0.014993  -0.024669
# restecg    0.131847 -0.100811  -0.012401
# thalach   -0.137970 -0.055431  -0.039567
# exang     -0.135155  0.154872  -0.106243
# oldpeak    0.234815  0.177563  -0.110228
# slope      0.056588  0.157251   0.030498
# ca         1.000000 -0.037430  -0.160356
# thal      -0.037430  1.000000   0.020061
# Mortality -0.160356  0.020061   1.000000

# %%
df.columns
# Out:
# Index(['Age', 'Age.Group', 'Gender', 'Locality', 'Marital_status', 'Sleep',
#        'Depression', 'Smoking', 'Diabetes', 'BP', 'Hypersensitivity', 'cp',
#        'trestbps', 'chol', 'fbs', 'restecg', 'thalach', 'exang', 'oldpeak',
#        'slope', 'ca', 'thal', 'Mortality'],
#       dtype='object')

# %% [markdown]
# Before LabelEncoder

# %%
df.head()
# Out:
#    Age Age.Group  Gender Locality Marital_status Sleep Depression Smoking  \
# 0   45     41-50  Female    RURAL        MARRIED    NO        YES      NO
# 1   51     51-60  Female    URBAN        MARRIED    NO        YES      NO
# 2   55     51-60  Female    RURAL        MARRIED   YES        YES      NO
# 3   55     51-60  Female    RURAL        MARRIED   YES        YES      NO
# 4   56     51-60  Female    RURAL        MARRIED    NO        YES      NO
#
#    Diabetes     BP  ... chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0         1  100.6  ...  341    1        2      136      1      3.0      2
# 1         0   90.6  ...  305    0        0      142      1      1.2      2
# 2         1  100.7  ...  327    0        1      117      1      3.4      2
# 3         1  160.1  ...  205    0        1      130      1      2.0      2
# 4         1   90.6  ...  288    1        2      133      1      4.0      3
#
#    ca  thal  Mortality
# 0   0     7          0
# 1   0     7          0
# 2   0     3          0
# 3   1     7          0
# 4   2     7          0
#
# [5 rows x 23 columns]

# %% [markdown]
# After LabelEncoder

# %%
from sklearn.preprocessing import LabelEncoder
var_mod = ['Gender', 'Locality', 'Marital_status', 'Sleep', 'Depression', 'Smoking', 'Hypersensitivity']
le = LabelEncoder()
for i in var_mod:
    df[i] = le.fit_transform(df[i]).astype(int)

# %%
df.head()
# Out:
#    Age Age.Group  Gender  Locality  Marital_status  Sleep  Depression  \
# 0   45     41-50       0         0               0      0           1
# 1   51     51-60       0         1               0      0           1
# 2   55     51-60       0         0               0      1           1
# 3   55     51-60       0         0               0      1           1
# 4   56     51-60       0         0               0      0           1
#
#    Smoking  Diabetes     BP  ...  chol  fbs  restecg  thalach  exang  oldpeak  \
# 0        0         1  100.6  ...   341    1        2      136      1      3.0
# 1        0         0   90.6  ...   305    0        0      142      1      1.2
# 2        0         1  100.7  ...   327    0        1      117      1      3.4
# 3        0         1  160.1  ...   205    0        1      130      1      2.0
# 4        0         1   90.6  ...   288    1        2      133      1      4.0
#
#    slope  ca  thal  Mortality
# 0      2   0     7          0
# 1      2   0     7          0
# 2      2   0     3          0
# 3      2   1     7          0
# 4      3   2     7          0
#
# [5 rows x 23 columns]
