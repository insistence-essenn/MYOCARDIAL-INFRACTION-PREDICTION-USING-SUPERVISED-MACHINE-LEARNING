# %% [markdown]
# # Data visualization:

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
sns.set()

# %%
data = pd.read_csv('heart.csv')

# %%
df = data.dropna()

# %%
df.columns
# Out:
# Index(['Age', 'Age.Group', 'Gender', 'Locality', 'Marital_status', 'Sleep',
#        'Depression', 'Smoking', 'Diabetes', 'BP', 'Hypersensitivity', 'cp',
#        'trestbps', 'chol', 'fbs', 'restecg', 'thalach', 'exang', 'oldpeak',
#        'slope', 'ca', 'thal', 'Mortality'],
#       dtype='object')

# %%
sns.countplot(x="Mortality", data=df, palette="husl")
# Out:
# <Axes: xlabel='Mortality', ylabel='count'>

# %%
df['Age'].hist(figsize=(5,5), color='brown', alpha=1)
plt.xlabel('Age')
plt.ylabel('Count')
plt.title('Age and its Count')
# Out:
# Text(0.5, 1.0, 'Age and its Count')

# %%
df['chol'].hist(figsize=(5,5), color='brown', alpha=1)
plt.xlabel('Chol')
plt.ylabel('Count')
plt.title('Age and its Count')
# Out:
# Text(0.5, 1.0, 'Age and its Count')

# %%
def piechart(df, variable):
    dataframe_pie = df[variable].value_counts()
    ax = dataframe_pie.plot.pie(figsize=(8,8), autopct='%1.2f%%', fontsize = 12)
    ax.set_title(variable + ' \n', fontsize = 15)

piechart(df, 'Smoking')

# %%
piechart(df, 'Gender')

# %%
df=load.dataset
g = sns.catplot("Mortality", data=df, kind='count', hue='Age', margin_titles=False)
g.set_ylabels('Number of persons')
g.fig.set_figheight(5)
g.fig.set_figwidth(20)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[11], line 1
# ----> 1 g = sns.catplot("Mortality", data=df, kind='count', hue='Age', margin_titles=False)
#       2 g.set_ylabels('Number of persons')
#       3 g.fig.set_figheight(5)
#
# TypeError: catplot() got multiple values for argument 'data'

# %%
sns.pairplot(df)

# %%
fig, ax = plt.subplots(figsize=(25,12))
sns.heatmap(df.corr(),annot = True, ax=ax)
plt.show()
